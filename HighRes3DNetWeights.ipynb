# %%
import re
from pathlib import Path
from collections import OrderedDict

import torch
import tensorflow as tf
from torchsummary import summary

import pandas as pd
# from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm

from highresnet import HighRes3DNet

# %%
output_csv_path = 'state_dict_tf.csv'
models_dir = Path('~/niftynet/models/').expanduser()
checkpoint_name = 'model.ckpt-33000'
checkpoint_path = models_dir / 'highres3dnet_brain_parcellation'/ 'models' / checkpoint_name

state_dict_tf_path = 'state_dict_tf.pth'
state_dict_pt_path = 'state_dict_pt.pth'

pd.set_option('display.max_colwidth', -1)  # do not truncate strings when displaying data frames
pd.set_option('display.max_rows', None)  # show all rows

filter_variables = True

# %% [markdown]
# ## TensorFlow

# %%
tf.reset_default_graph()

rows = []
variables_dict = OrderedDict()
variables_list = tf.train.list_variables(str(checkpoint_path))
for name, shape in variables_list:
    if filter_variables:
        if (
            'Adam' in name  # used for training
            or 'biased' in name  # I don't what these are
            or not shape  # empty variables
        ):
            continue
    variables_dict[name] = tf.get_variable(name, shape=shape)
    name = name.replace('HighRes3DNet/', '')
    shape = ', '.join(str(n) for n in shape)
    row = {'name': name, 'shape': shape}
    rows.append(row)
df_tf = pd.DataFrame.from_dict(rows)
df_tf
# Out:
#                                                   name             shape
# 0    conv_0_bn_relu/bn_/beta                            16
# 1    conv_0_bn_relu/bn_/beta/ExponentialMovingAverage   16
# 2    conv_0_bn_relu/bn_/gamma                           16
# 3    conv_0_bn_relu/bn_/gamma/ExponentialMovingAverage  16
# 4    conv_0_bn_relu/bn_/moving_mean                     16
# 5    conv_0_bn_relu/bn_/moving_variance                 16
# 6    conv_0_bn_relu/conv_/w                             3, 3, 3, 1, 16
# 7    conv_0_bn_relu/conv_/w/ExponentialMovingAverage    3, 3, 3, 1, 16
# 8    conv_1_bn_relu/bn_/beta                            80
# 9    conv_1_bn_relu/bn_/beta/ExponentialMovingAverage   80
# 10   conv_1_bn_relu/bn_/gamma                           80
# 11   conv_1_bn_relu/bn_/gamma/ExponentialMovingAverage  80
# 12   conv_1_bn_relu/bn_/moving_mean                     80
# 13   conv_1_bn_relu/bn_/moving_variance                 80
# 14   conv_1_bn_relu/conv_/w                             1, 1, 1, 64, 80
# 15   conv_1_bn_relu/conv_/w/ExponentialMovingAverage    1, 1, 1, 64, 80
# 16   conv_2_bn/bn_/beta                                 160
# 17   conv_2_bn/bn_/beta/ExponentialMovingAverage        160
# 18   conv_2_bn/bn_/gamma                                160
# 19   conv_2_bn/bn_/gamma/ExponentialMovingAverage       160
# 20   conv_2_bn/bn_/moving_mean                          160
# 21   conv_2_bn/bn_/moving_variance                      160
# 22   conv_2_bn/conv_/w                                  1, 1, 1, 80, 160
# 23   conv_2_bn/conv_/w/ExponentialMovingAverage         1, 1, 1, 80, 160
# 24   res_1_0/bn_0/beta                                  16
# 25   res_1_0/bn_0/beta/ExponentialMovingAverage         16
# 26   res_1_0/bn_0/gamma                                 16
# 27   res_1_0/bn_0/gamma/ExponentialMovingAverage        16
# 28   res_1_0/bn_0/moving_mean                           16
# 29   res_1_0/bn_0/moving_variance                       16
# 30   res_1_0/bn_1/beta                                  16
# 31   res_1_0/bn_1/beta/ExponentialMovingAverage         16
# 32   res_1_0/bn_1/gamma                                 16
# 33   res_1_0/bn_1/gamma/ExponentialMovingAverage        16
# 34   res_1_0/bn_1/moving_mean                           16
# 35   res_1_0/bn_1/moving_variance                       16
# 36   res_1_0/conv_0/w                                   3, 3, 3, 16, 16
# 37   res_1_0/conv_0/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 38   res_1_0/conv_1/w                                   3, 3, 3, 16, 16
# 39   res_1_0/conv_1/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 40   res_1_1/bn_0/beta                                  16
# 41   res_1_1/bn_0/beta/ExponentialMovingAverage         16
# 42   res_1_1/bn_0/gamma                                 16
# 43   res_1_1/bn_0/gamma/ExponentialMovingAverage        16
# 44   res_1_1/bn_0/moving_mean                           16
# 45   res_1_1/bn_0/moving_variance                       16
# 46   res_1_1/bn_1/beta                                  16
# 47   res_1_1/bn_1/beta/ExponentialMovingAverage         16
# 48   res_1_1/bn_1/gamma                                 16
# 49   res_1_1/bn_1/gamma/ExponentialMovingAverage        16
# 50   res_1_1/bn_1/moving_mean                           16
# 51   res_1_1/bn_1/moving_variance                       16
# 52   res_1_1/conv_0/w                                   3, 3, 3, 16, 16
# 53   res_1_1/conv_0/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 54   res_1_1/conv_1/w                                   3, 3, 3, 16, 16
# 55   res_1_1/conv_1/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 56   res_1_2/bn_0/beta                                  16
# 57   res_1_2/bn_0/beta/ExponentialMovingAverage         16
# 58   res_1_2/bn_0/gamma                                 16
# 59   res_1_2/bn_0/gamma/ExponentialMovingAverage        16
# 60   res_1_2/bn_0/moving_mean                           16
# 61   res_1_2/bn_0/moving_variance                       16
# 62   res_1_2/bn_1/beta                                  16
# 63   res_1_2/bn_1/beta/ExponentialMovingAverage         16
# 64   res_1_2/bn_1/gamma                                 16
# 65   res_1_2/bn_1/gamma/ExponentialMovingAverage        16
# 66   res_1_2/bn_1/moving_mean                           16
# 67   res_1_2/bn_1/moving_variance                       16
# 68   res_1_2/conv_0/w                                   3, 3, 3, 16, 16
# 69   res_1_2/conv_0/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 70   res_1_2/conv_1/w                                   3, 3, 3, 16, 16
# 71   res_1_2/conv_1/w/ExponentialMovingAverage          3, 3, 3, 16, 16
# 72   res_2_0/bn_0/beta                                  16
# 73   res_2_0/bn_0/beta/ExponentialMovingAverage         16
# 74   res_2_0/bn_0/gamma                                 16
# 75   res_2_0/bn_0/gamma/ExponentialMovingAverage        16
# 76   res_2_0/bn_0/moving_mean                           16
# 77   res_2_0/bn_0/moving_variance                       16
# 78   res_2_0/bn_1/beta                                  32
# 79   res_2_0/bn_1/beta/ExponentialMovingAverage         32
# 80   res_2_0/bn_1/gamma                                 32
# 81   res_2_0/bn_1/gamma/ExponentialMovingAverage        32
# 82   res_2_0/bn_1/moving_mean                           32
# 83   res_2_0/bn_1/moving_variance                       32
# 84   res_2_0/conv_0/w                                   3, 3, 3, 16, 32
# 85   res_2_0/conv_0/w/ExponentialMovingAverage          3, 3, 3, 16, 32
# 86   res_2_0/conv_1/w                                   3, 3, 3, 32, 32
# 87   res_2_0/conv_1/w/ExponentialMovingAverage          3, 3, 3, 32, 32
# 88   res_2_1/bn_0/beta                                  32
# 89   res_2_1/bn_0/beta/ExponentialMovingAverage         32
# 90   res_2_1/bn_0/gamma                                 32
# 91   res_2_1/bn_0/gamma/ExponentialMovingAverage        32
# 92   res_2_1/bn_0/moving_mean                           32
# 93   res_2_1/bn_0/moving_variance                       32
# 94   res_2_1/bn_1/beta                                  32
# 95   res_2_1/bn_1/beta/ExponentialMovingAverage         32
# 96   res_2_1/bn_1/gamma                                 32
# 97   res_2_1/bn_1/gamma/ExponentialMovingAverage        32
# 98   res_2_1/bn_1/moving_mean                           32
# 99   res_2_1/bn_1/moving_variance                       32
# 100  res_2_1/conv_0/w                                   3, 3, 3, 32, 32
# 101  res_2_1/conv_0/w/ExponentialMovingAverage          3, 3, 3, 32, 32
# 102  res_2_1/conv_1/w                                   3, 3, 3, 32, 32
# 103  res_2_1/conv_1/w/ExponentialMovingAverage          3, 3, 3, 32, 32
# 104  res_2_2/bn_0/beta                                  32
# 105  res_2_2/bn_0/beta/ExponentialMovingAverage         32
# 106  res_2_2/bn_0/gamma                                 32
# 107  res_2_2/bn_0/gamma/ExponentialMovingAverage        32
# 108  res_2_2/bn_0/moving_mean                           32
# 109  res_2_2/bn_0/moving_variance                       32
# 110  res_2_2/bn_1/beta                                  32
# 111  res_2_2/bn_1/beta/ExponentialMovingAverage         32
# 112  res_2_2/bn_1/gamma                                 32
# 113  res_2_2/bn_1/gamma/ExponentialMovingAverage        32
# 114  res_2_2/bn_1/moving_mean                           32
# 115  res_2_2/bn_1/moving_variance                       32
# 116  res_2_2/conv_0/w                                   3, 3, 3, 32, 32
# 117  res_2_2/conv_0/w/ExponentialMovingAverage          3, 3, 3, 32, 32
# 118  res_2_2/conv_1/w                                   3, 3, 3, 32, 32
# 119  res_2_2/conv_1/w/ExponentialMovingAverage          3, 3, 3, 32, 32
# 120  res_3_0/bn_0/beta                                  32
# 121  res_3_0/bn_0/beta/ExponentialMovingAverage         32
# 122  res_3_0/bn_0/gamma                                 32
# 123  res_3_0/bn_0/gamma/ExponentialMovingAverage        32
# 124  res_3_0/bn_0/moving_mean                           32
# 125  res_3_0/bn_0/moving_variance                       32
# 126  res_3_0/bn_1/beta                                  64
# 127  res_3_0/bn_1/beta/ExponentialMovingAverage         64
# 128  res_3_0/bn_1/gamma                                 64
# 129  res_3_0/bn_1/gamma/ExponentialMovingAverage        64
# 130  res_3_0/bn_1/moving_mean                           64
# 131  res_3_0/bn_1/moving_variance                       64
# 132  res_3_0/conv_0/w                                   3, 3, 3, 32, 64
# 133  res_3_0/conv_0/w/ExponentialMovingAverage          3, 3, 3, 32, 64
# 134  res_3_0/conv_1/w                                   3, 3, 3, 64, 64
# 135  res_3_0/conv_1/w/ExponentialMovingAverage          3, 3, 3, 64, 64
# 136  res_3_1/bn_0/beta                                  64
# 137  res_3_1/bn_0/beta/ExponentialMovingAverage         64
# 138  res_3_1/bn_0/gamma                                 64
# 139  res_3_1/bn_0/gamma/ExponentialMovingAverage        64
# 140  res_3_1/bn_0/moving_mean                           64
# 141  res_3_1/bn_0/moving_variance                       64
# 142  res_3_1/bn_1/beta                                  64
# 143  res_3_1/bn_1/beta/ExponentialMovingAverage         64
# 144  res_3_1/bn_1/gamma                                 64
# 145  res_3_1/bn_1/gamma/ExponentialMovingAverage        64
# 146  res_3_1/bn_1/moving_mean                           64
# 147  res_3_1/bn_1/moving_variance                       64
# 148  res_3_1/conv_0/w                                   3, 3, 3, 64, 64
# 149  res_3_1/conv_0/w/ExponentialMovingAverage          3, 3, 3, 64, 64
# 150  res_3_1/conv_1/w                                   3, 3, 3, 64, 64
# 151  res_3_1/conv_1/w/ExponentialMovingAverage          3, 3, 3, 64, 64
# 152  res_3_2/bn_0/beta                                  64
# 153  res_3_2/bn_0/beta/ExponentialMovingAverage         64
# 154  res_3_2/bn_0/gamma                                 64
# 155  res_3_2/bn_0/gamma/ExponentialMovingAverage        64
# 156  res_3_2/bn_0/moving_mean                           64
# 157  res_3_2/bn_0/moving_variance                       64
# 158  res_3_2/bn_1/beta                                  64
# 159  res_3_2/bn_1/beta/ExponentialMovingAverage         64
# 160  res_3_2/bn_1/gamma                                 64
# 161  res_3_2/bn_1/gamma/ExponentialMovingAverage        64
# 162  res_3_2/bn_1/moving_mean                           64
# 163  res_3_2/bn_1/moving_variance                       64
# 164  res_3_2/conv_0/w                                   3, 3, 3, 64, 64
# 165  res_3_2/conv_0/w/ExponentialMovingAverage          3, 3, 3, 64, 64
# 166  res_3_2/conv_1/w                                   3, 3, 3, 64, 64
# 167  res_3_2/conv_1/w/ExponentialMovingAverage          3, 3, 3, 64, 64

# %%
saver = tf.train.Saver()
state_dict_tf = {}
with tf.Session() as sess:
    print('Restoring session...')
    saver.restore(sess, str(checkpoint_path))
    for name, shape in tqdm(variables_list):
        if filter_variables:
            if (
                'Adam' in name
                or 'biased' in name
                or not shape
            ):
                continue
        array = variables_dict[name].eval()
        name = name.replace('HighRes3DNet/', '')
        state_dict_tf[name] = torch.tensor(array)
print('Saving state dictionary...')
torch.save(state_dict_tf, state_dict_tf_path)
# Out:
# Restoring session...
# INFO:tensorflow:Restoring parameters from /home/fernando/niftynet/models/highres3dnet_brain_parcellation/models/model.ckpt-33000
# 100%|██████████| 380/380 [00:03<00:00, 87.72it/s]
# Saving state dictionary...

# %% [markdown]
# ## PyTorch

# %%
model = HighRes3DNet(1, 160, add_dropout_layer=True)
from torchsummary import summary
summary(model, input_size=(1, 12, 12, 12), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#              Pad3d-1        [-1, 1, 14, 14, 14]               0
#             Conv3d-2       [-1, 16, 12, 12, 12]             432
#        BatchNorm3d-3       [-1, 16, 12, 12, 12]              32
#               ReLU-4       [-1, 16, 12, 12, 12]               0
# ConvolutionalBlock-5       [-1, 16, 12, 12, 12]               0
#        BatchNorm3d-6       [-1, 16, 12, 12, 12]              32
#               ReLU-7       [-1, 16, 12, 12, 12]               0
#              Pad3d-8       [-1, 16, 14, 14, 14]               0
#             Conv3d-9       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-10       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-11       [-1, 16, 12, 12, 12]              32
#              ReLU-12       [-1, 16, 12, 12, 12]               0
#             Pad3d-13       [-1, 16, 14, 14, 14]               0
#            Conv3d-14       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-15       [-1, 16, 12, 12, 12]               0
#     ResidualBlock-16       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-17       [-1, 16, 12, 12, 12]              32
#              ReLU-18       [-1, 16, 12, 12, 12]               0
#             Pad3d-19       [-1, 16, 14, 14, 14]               0
#            Conv3d-20       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-21       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-22       [-1, 16, 12, 12, 12]              32
#              ReLU-23       [-1, 16, 12, 12, 12]               0
#             Pad3d-24       [-1, 16, 14, 14, 14]               0
#            Conv3d-25       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-26       [-1, 16, 12, 12, 12]               0
#     ResidualBlock-27       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-28       [-1, 16, 12, 12, 12]              32
#              ReLU-29       [-1, 16, 12, 12, 12]               0
#             Pad3d-30       [-1, 16, 14, 14, 14]               0
#            Conv3d-31       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-32       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-33       [-1, 16, 12, 12, 12]              32
#              ReLU-34       [-1, 16, 12, 12, 12]               0
#             Pad3d-35       [-1, 16, 14, 14, 14]               0
#            Conv3d-36       [-1, 16, 12, 12, 12]           6,912
# ConvolutionalBlock-37       [-1, 16, 12, 12, 12]               0
#     ResidualBlock-38       [-1, 16, 12, 12, 12]               0
#     DilationBlock-39       [-1, 16, 12, 12, 12]               0
#       BatchNorm3d-40       [-1, 16, 12, 12, 12]              32
#              ReLU-41       [-1, 16, 12, 12, 12]               0
#             Pad3d-42       [-1, 16, 16, 16, 16]               0
#            Conv3d-43       [-1, 32, 12, 12, 12]          13,824
# ConvolutionalBlock-44       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-45       [-1, 32, 12, 12, 12]              64
#              ReLU-46       [-1, 32, 12, 12, 12]               0
#             Pad3d-47       [-1, 32, 16, 16, 16]               0
#            Conv3d-48       [-1, 32, 12, 12, 12]          27,648
# ConvolutionalBlock-49       [-1, 32, 12, 12, 12]               0
#     ResidualBlock-50       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-51       [-1, 32, 12, 12, 12]              64
#              ReLU-52       [-1, 32, 12, 12, 12]               0
#             Pad3d-53       [-1, 32, 16, 16, 16]               0
#            Conv3d-54       [-1, 32, 12, 12, 12]          27,648
# ConvolutionalBlock-55       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-56       [-1, 32, 12, 12, 12]              64
#              ReLU-57       [-1, 32, 12, 12, 12]               0
#             Pad3d-58       [-1, 32, 16, 16, 16]               0
#            Conv3d-59       [-1, 32, 12, 12, 12]          27,648
# ConvolutionalBlock-60       [-1, 32, 12, 12, 12]               0
#     ResidualBlock-61       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-62       [-1, 32, 12, 12, 12]              64
#              ReLU-63       [-1, 32, 12, 12, 12]               0
#             Pad3d-64       [-1, 32, 16, 16, 16]               0
#            Conv3d-65       [-1, 32, 12, 12, 12]          27,648
# ConvolutionalBlock-66       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-67       [-1, 32, 12, 12, 12]              64
#              ReLU-68       [-1, 32, 12, 12, 12]               0
#             Pad3d-69       [-1, 32, 16, 16, 16]               0
#            Conv3d-70       [-1, 32, 12, 12, 12]          27,648
# ConvolutionalBlock-71       [-1, 32, 12, 12, 12]               0
#     ResidualBlock-72       [-1, 32, 12, 12, 12]               0
#     DilationBlock-73       [-1, 32, 12, 12, 12]               0
#       BatchNorm3d-74       [-1, 32, 12, 12, 12]              64
#              ReLU-75       [-1, 32, 12, 12, 12]               0
#             Pad3d-76       [-1, 32, 20, 20, 20]               0
#            Conv3d-77       [-1, 64, 12, 12, 12]          55,296
# ConvolutionalBlock-78       [-1, 64, 12, 12, 12]               0
#       BatchNorm3d-79       [-1, 64, 12, 12, 12]             128
#              ReLU-80       [-1, 64, 12, 12, 12]               0
#             Pad3d-81       [-1, 64, 20, 20, 20]               0
#            Conv3d-82       [-1, 64, 12, 12, 12]         110,592
# ConvolutionalBlock-83       [-1, 64, 12, 12, 12]               0
#     ResidualBlock-84       [-1, 64, 12, 12, 12]               0
#       BatchNorm3d-85       [-1, 64, 12, 12, 12]             128
#              ReLU-86       [-1, 64, 12, 12, 12]               0
#             Pad3d-87       [-1, 64, 20, 20, 20]               0
#            Conv3d-88       [-1, 64, 12, 12, 12]         110,592
# ConvolutionalBlock-89       [-1, 64, 12, 12, 12]               0
#       BatchNorm3d-90       [-1, 64, 12, 12, 12]             128
#              ReLU-91       [-1, 64, 12, 12, 12]               0
#             Pad3d-92       [-1, 64, 20, 20, 20]               0
#            Conv3d-93       [-1, 64, 12, 12, 12]         110,592
# ConvolutionalBlock-94       [-1, 64, 12, 12, 12]               0
#     ResidualBlock-95       [-1, 64, 12, 12, 12]               0
#       BatchNorm3d-96       [-1, 64, 12, 12, 12]             128
#              ReLU-97       [-1, 64, 12, 12, 12]               0
#             Pad3d-98       [-1, 64, 20, 20, 20]               0
#            Conv3d-99       [-1, 64, 12, 12, 12]         110,592
# ConvolutionalBlock-100       [-1, 64, 12, 12, 12]               0
#      BatchNorm3d-101       [-1, 64, 12, 12, 12]             128
#             ReLU-102       [-1, 64, 12, 12, 12]               0
#            Pad3d-103       [-1, 64, 20, 20, 20]               0
#           Conv3d-104       [-1, 64, 12, 12, 12]         110,592
# ConvolutionalBlock-105       [-1, 64, 12, 12, 12]               0
#    ResidualBlock-106       [-1, 64, 12, 12, 12]               0
#    DilationBlock-107       [-1, 64, 12, 12, 12]               0
#           Conv3d-108       [-1, 80, 12, 12, 12]           5,120
#      BatchNorm3d-109       [-1, 80, 12, 12, 12]             160
#             ReLU-110       [-1, 80, 12, 12, 12]               0
# ConvolutionalBlock-111       [-1, 80, 12, 12, 12]               0
#        Dropout3d-112       [-1, 80, 12, 12, 12]               0
#           Conv3d-113      [-1, 160, 12, 12, 12]          12,800
#      BatchNorm3d-114      [-1, 160, 12, 12, 12]             320
# ConvolutionalBlock-115      [-1, 160, 12, 12, 12]               0
#          Softmax-116      [-1, 160, 12, 12, 12]               0
# ================================================================
# Total params: 821,904
# Trainable params: 821,904
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 83.65
# Params size (MB): 3.14
# Estimated Total Size (MB): 86.79
# ----------------------------------------------------------------

# %%
model
# Out:
# HighRes3DNet(
#   (block): Sequential(
#     (0): ConvolutionalBlock(
#       (convolutional_block): Sequential(
#         (0): Pad3d()
#         (1): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#         (2): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU()
#       )
#     )
#     (1): DilationBlock(
#       (dilation_block): Sequential(
#         (0): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (1): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (2): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DilationBlock(
#       (dilation_block): Sequential(
#         (0): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#           )
#         )
#         (1): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#           )
#         )
#         (2): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(2, 2, 2), bias=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (3): DilationBlock(
#       (dilation_block): Sequential(
#         (0): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#           )
#         )
#         (1): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#           )
#         )
#         (2): ResidualBlock(
#           (residual_block): Sequential(
#             (0): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#             (1): ConvolutionalBlock(
#               (convolutional_block): Sequential(
#                 (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): ReLU()
#                 (2): Pad3d()
#                 (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), dilation=(4, 4, 4), bias=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (4): ConvolutionalBlock(
#       (convolutional_block): Sequential(
#         (0): Conv3d(64, 80, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (5): Dropout3d(p=0.5)
#     (6): ConvolutionalBlock(
#       (convolutional_block): Sequential(
#         (0): Conv3d(80, 160, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Softmax()
#   )
# )

# %%
state_dict_pt = model.state_dict()
rows = []
for name, parameters in state_dict_pt.items():
    shape = ', '.join(str(n) for n in parameters.shape)
    row = {'name': name, 'shape': shape}
    rows.append(row)
df_pt = pd.DataFrame.from_dict(rows)
df_pt.style.set_properties(**{'text-align': 'left'})
df_pt
# Out:
#                                                                                     name  \
# 0    block.0.convolutional_block.1.weight
# 1    block.0.convolutional_block.2.weight
# 2    block.0.convolutional_block.2.bias
# 3    block.0.convolutional_block.2.running_mean
# 4    block.0.convolutional_block.2.running_var
# 5    block.0.convolutional_block.2.num_batches_tracked
# 6    block.1.dilation_block.0.residual_block.0.convolutional_block.0.weight
# 7    block.1.dilation_block.0.residual_block.0.convolutional_block.0.bias
# 8    block.1.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
# 9    block.1.dilation_block.0.residual_block.0.convolutional_block.0.running_var
# 10   block.1.dilation_block.0.residual_block.0.convolutional_block.0.num_batches_tracked
# 11   block.1.dilation_block.0.residual_block.0.convolutional_block.3.weight
# 12   block.1.dilation_block.0.residual_block.1.convolutional_block.0.weight
# 13   block.1.dilation_block.0.residual_block.1.convolutional_block.0.bias
# 14   block.1.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
# 15   block.1.dilation_block.0.residual_block.1.convolutional_block.0.running_var
# 16   block.1.dilation_block.0.residual_block.1.convolutional_block.0.num_batches_tracked
# 17   block.1.dilation_block.0.residual_block.1.convolutional_block.3.weight
# 18   block.1.dilation_block.1.residual_block.0.convolutional_block.0.weight
# 19   block.1.dilation_block.1.residual_block.0.convolutional_block.0.bias
# 20   block.1.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
# 21   block.1.dilation_block.1.residual_block.0.convolutional_block.0.running_var
# 22   block.1.dilation_block.1.residual_block.0.convolutional_block.0.num_batches_tracked
# 23   block.1.dilation_block.1.residual_block.0.convolutional_block.3.weight
# 24   block.1.dilation_block.1.residual_block.1.convolutional_block.0.weight
# 25   block.1.dilation_block.1.residual_block.1.convolutional_block.0.bias
# 26   block.1.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
# 27   block.1.dilation_block.1.residual_block.1.convolutional_block.0.running_var
# 28   block.1.dilation_block.1.residual_block.1.convolutional_block.0.num_batches_tracked
# 29   block.1.dilation_block.1.residual_block.1.convolutional_block.3.weight
# 30   block.1.dilation_block.2.residual_block.0.convolutional_block.0.weight
# 31   block.1.dilation_block.2.residual_block.0.convolutional_block.0.bias
# 32   block.1.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
# 33   block.1.dilation_block.2.residual_block.0.convolutional_block.0.running_var
# 34   block.1.dilation_block.2.residual_block.0.convolutional_block.0.num_batches_tracked
# 35   block.1.dilation_block.2.residual_block.0.convolutional_block.3.weight
# 36   block.1.dilation_block.2.residual_block.1.convolutional_block.0.weight
# 37   block.1.dilation_block.2.residual_block.1.convolutional_block.0.bias
# 38   block.1.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
# 39   block.1.dilation_block.2.residual_block.1.convolutional_block.0.running_var
# 40   block.1.dilation_block.2.residual_block.1.convolutional_block.0.num_batches_tracked
# 41   block.1.dilation_block.2.residual_block.1.convolutional_block.3.weight
# 42   block.2.dilation_block.0.residual_block.0.convolutional_block.0.weight
# 43   block.2.dilation_block.0.residual_block.0.convolutional_block.0.bias
# 44   block.2.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
# 45   block.2.dilation_block.0.residual_block.0.convolutional_block.0.running_var
# 46   block.2.dilation_block.0.residual_block.0.convolutional_block.0.num_batches_tracked
# 47   block.2.dilation_block.0.residual_block.0.convolutional_block.3.weight
# 48   block.2.dilation_block.0.residual_block.1.convolutional_block.0.weight
# 49   block.2.dilation_block.0.residual_block.1.convolutional_block.0.bias
# 50   block.2.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
# 51   block.2.dilation_block.0.residual_block.1.convolutional_block.0.running_var
# 52   block.2.dilation_block.0.residual_block.1.convolutional_block.0.num_batches_tracked
# 53   block.2.dilation_block.0.residual_block.1.convolutional_block.3.weight
# 54   block.2.dilation_block.1.residual_block.0.convolutional_block.0.weight
# 55   block.2.dilation_block.1.residual_block.0.convolutional_block.0.bias
# 56   block.2.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
# 57   block.2.dilation_block.1.residual_block.0.convolutional_block.0.running_var
# 58   block.2.dilation_block.1.residual_block.0.convolutional_block.0.num_batches_tracked
# 59   block.2.dilation_block.1.residual_block.0.convolutional_block.3.weight
# 60   block.2.dilation_block.1.residual_block.1.convolutional_block.0.weight
# 61   block.2.dilation_block.1.residual_block.1.convolutional_block.0.bias
# 62   block.2.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
# 63   block.2.dilation_block.1.residual_block.1.convolutional_block.0.running_var
# 64   block.2.dilation_block.1.residual_block.1.convolutional_block.0.num_batches_tracked
# 65   block.2.dilation_block.1.residual_block.1.convolutional_block.3.weight
# 66   block.2.dilation_block.2.residual_block.0.convolutional_block.0.weight
# 67   block.2.dilation_block.2.residual_block.0.convolutional_block.0.bias
# 68   block.2.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
# 69   block.2.dilation_block.2.residual_block.0.convolutional_block.0.running_var
# 70   block.2.dilation_block.2.residual_block.0.convolutional_block.0.num_batches_tracked
# 71   block.2.dilation_block.2.residual_block.0.convolutional_block.3.weight
# 72   block.2.dilation_block.2.residual_block.1.convolutional_block.0.weight
# 73   block.2.dilation_block.2.residual_block.1.convolutional_block.0.bias
# 74   block.2.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
# 75   block.2.dilation_block.2.residual_block.1.convolutional_block.0.running_var
# 76   block.2.dilation_block.2.residual_block.1.convolutional_block.0.num_batches_tracked
# 77   block.2.dilation_block.2.residual_block.1.convolutional_block.3.weight
# 78   block.3.dilation_block.0.residual_block.0.convolutional_block.0.weight
# 79   block.3.dilation_block.0.residual_block.0.convolutional_block.0.bias
# 80   block.3.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
# 81   block.3.dilation_block.0.residual_block.0.convolutional_block.0.running_var
# 82   block.3.dilation_block.0.residual_block.0.convolutional_block.0.num_batches_tracked
# 83   block.3.dilation_block.0.residual_block.0.convolutional_block.3.weight
# 84   block.3.dilation_block.0.residual_block.1.convolutional_block.0.weight
# 85   block.3.dilation_block.0.residual_block.1.convolutional_block.0.bias
# 86   block.3.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
# 87   block.3.dilation_block.0.residual_block.1.convolutional_block.0.running_var
# 88   block.3.dilation_block.0.residual_block.1.convolutional_block.0.num_batches_tracked
# 89   block.3.dilation_block.0.residual_block.1.convolutional_block.3.weight
# 90   block.3.dilation_block.1.residual_block.0.convolutional_block.0.weight
# 91   block.3.dilation_block.1.residual_block.0.convolutional_block.0.bias
# 92   block.3.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
# 93   block.3.dilation_block.1.residual_block.0.convolutional_block.0.running_var
# 94   block.3.dilation_block.1.residual_block.0.convolutional_block.0.num_batches_tracked
# 95   block.3.dilation_block.1.residual_block.0.convolutional_block.3.weight
# 96   block.3.dilation_block.1.residual_block.1.convolutional_block.0.weight
# 97   block.3.dilation_block.1.residual_block.1.convolutional_block.0.bias
# 98   block.3.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
# 99   block.3.dilation_block.1.residual_block.1.convolutional_block.0.running_var
# 100  block.3.dilation_block.1.residual_block.1.convolutional_block.0.num_batches_tracked
# 101  block.3.dilation_block.1.residual_block.1.convolutional_block.3.weight
# 102  block.3.dilation_block.2.residual_block.0.convolutional_block.0.weight
# 103  block.3.dilation_block.2.residual_block.0.convolutional_block.0.bias
# 104  block.3.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
# 105  block.3.dilation_block.2.residual_block.0.convolutional_block.0.running_var
# 106  block.3.dilation_block.2.residual_block.0.convolutional_block.0.num_batches_tracked
# 107  block.3.dilation_block.2.residual_block.0.convolutional_block.3.weight
# 108  block.3.dilation_block.2.residual_block.1.convolutional_block.0.weight
# 109  block.3.dilation_block.2.residual_block.1.convolutional_block.0.bias
# 110  block.3.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
# 111  block.3.dilation_block.2.residual_block.1.convolutional_block.0.running_var
# 112  block.3.dilation_block.2.residual_block.1.convolutional_block.0.num_batches_tracked
# 113  block.3.dilation_block.2.residual_block.1.convolutional_block.3.weight
# 114  block.4.convolutional_block.0.weight
# 115  block.4.convolutional_block.1.weight
# 116  block.4.convolutional_block.1.bias
# 117  block.4.convolutional_block.1.running_mean
# 118  block.4.convolutional_block.1.running_var
# 119  block.4.convolutional_block.1.num_batches_tracked
# 120  block.6.convolutional_block.0.weight
# 121  block.6.convolutional_block.1.weight
# 122  block.6.convolutional_block.1.bias
# 123  block.6.convolutional_block.1.running_mean
# 124  block.6.convolutional_block.1.running_var
# 125  block.6.convolutional_block.1.num_batches_tracked
#
#                 shape
# 0    16, 1, 3, 3, 3
# 1    16
# 2    16
# 3    16
# 4    16
# 5
# 6    16
# 7    16
# 8    16
# 9    16
# 10
# 11   16, 16, 3, 3, 3
# 12   16
# 13   16
# 14   16
# 15   16
# 16
# 17   16, 16, 3, 3, 3
# 18   16
# 19   16
# 20   16
# 21   16
# 22
# 23   16, 16, 3, 3, 3
# 24   16
# 25   16
# 26   16
# 27   16
# 28
# 29   16, 16, 3, 3, 3
# 30   16
# 31   16
# 32   16
# 33   16
# 34
# 35   16, 16, 3, 3, 3
# 36   16
# 37   16
# 38   16
# 39   16
# 40
# 41   16, 16, 3, 3, 3
# 42   16
# 43   16
# 44   16
# 45   16
# 46
# 47   32, 16, 3, 3, 3
# 48   32
# 49   32
# 50   32
# 51   32
# 52
# 53   32, 32, 3, 3, 3
# 54   32
# 55   32
# 56   32
# 57   32
# 58
# 59   32, 32, 3, 3, 3
# 60   32
# 61   32
# 62   32
# 63   32
# 64
# 65   32, 32, 3, 3, 3
# 66   32
# 67   32
# 68   32
# 69   32
# 70
# 71   32, 32, 3, 3, 3
# 72   32
# 73   32
# 74   32
# 75   32
# 76
# 77   32, 32, 3, 3, 3
# 78   32
# 79   32
# 80   32
# 81   32
# 82
# 83   64, 32, 3, 3, 3
# 84   64
# 85   64
# 86   64
# 87   64
# 88
# 89   64, 64, 3, 3, 3
# 90   64
# 91   64
# 92   64
# 93   64
# 94
# 95   64, 64, 3, 3, 3
# 96   64
# 97   64
# 98   64
# 99   64
# 100
# 101  64, 64, 3, 3, 3
# 102  64
# 103  64
# 104  64
# 105  64
# 106
# 107  64, 64, 3, 3, 3
# 108  64
# 109  64
# 110  64
# 111  64
# 112
# 113  64, 64, 3, 3, 3
# 114  80, 64, 1, 1, 1
# 115  80
# 116  80
# 117  80
# 118  80
# 119
# 120  160, 80, 1, 1, 1
# 121  160
# 122  160
# 123  160
# 124  160
# 125

# %%
def tf2pt_name(name_tf):
    param_type_dict = {
        'w': 'weight',
        'gamma': 'weight',
        'beta': 'bias',
        'moving_mean': 'running_mean',
        'moving_variance': 'running_var',
    }
    
    if name_tf.startswith('res_'):
        # res_2_0/bn_0/moving_variance
        pattern = (
            'res'
            r'_(\d)'  # 2 dil_idx
            r'_(\d)'  # 0 res_idx
            r'/(\w+)' # bn layer_type
            r'_(\d)'  # 0 layer_idx
            r'/(\w+)'  # moving_variance param_type
        )
        groups = re.match(pattern, name_tf).groups()
        dil_idx, res_idx, layer_type, layer_idx, param_type = groups
        param_idx = 3 if layer_type == 'conv' else 0
            
        name_pt = (
            f'block.{dil_idx}.dilation_block.{res_idx}.residual_block'
            f'.{layer_idx}.convolutional_block.{param_idx}.{param_type_dict[param_type]}'
        )
    elif name_tf.startswith('conv_'):
        conv_layers_dict = {
            'conv_0_bn_relu/conv_/w': 'block.0.convolutional_block.1.weight',  # first conv layer
            'conv_0_bn_relu/bn_/gamma': 'block.0.convolutional_block.2.weight',  
            'conv_0_bn_relu/bn_/beta': 'block.0.convolutional_block.2.bias',
            'conv_0_bn_relu/bn_/moving_mean': 'block.0.convolutional_block.2.running_mean',
            'conv_0_bn_relu/bn_/moving_variance': 'block.0.convolutional_block.2.running_var',

            'conv_1_bn_relu/conv_/w': 'block.4.convolutional_block.0.weight',  # layer with dropout
            'conv_1_bn_relu/bn_/gamma': 'block.4.convolutional_block.1.weight',  
            'conv_1_bn_relu/bn_/beta': 'block.4.convolutional_block.1.bias',
            'conv_1_bn_relu/bn_/moving_mean': 'block.4.convolutional_block.1.running_mean',
            'conv_1_bn_relu/bn_/moving_variance': 'block.4.convolutional_block.1.running_var',

            'conv_2_bn/conv_/w': 'block.6.convolutional_block.0.weight',  # layer with dropout
            'conv_2_bn/bn_/gamma': 'block.6.convolutional_block.1.weight',  
            'conv_2_bn/bn_/beta': 'block.6.convolutional_block.1.bias',
            'conv_2_bn/bn_/moving_mean': 'block.6.convolutional_block.1.running_mean',
            'conv_2_bn/bn_/moving_variance': 'block.6.convolutional_block.1.running_var',
        }
        name_pt = conv_layers_dict[name_tf]
    return name_pt
    
    
def tf2pt(name_tf, tensor_tf):
    name_pt = tf2pt_name(name_tf)
    num_dimensions = tensor_tf.dim()
    if num_dimensions == 1:
        tensor_pt = tensor_tf
    elif num_dimensions == 5:
        tensor_pt = tensor_tf.permute(4, 3, 0, 1, 2)
    return name_pt, tensor_pt

# %%
print('State ditionary will be saved to', state_dict_pt_path)
for name_tf, tensor_tf in tqdm(list(state_dict_tf.items())):
#     # To use variables with exponential moving average
#     if name_tf + '/ExponentialMovingAverage' in state_dict_tf:
#         continue

    # To NOT use exp moving avg
    if '/ExponentialMovingAverage' in name_tf:
        continue
    
    shape_tf = tuple(tensor_tf.shape)
    print(f'{str(shape_tf):18}', name_tf) 
    
    # To use variables with exponential moving average
    name_tf = name_tf.replace('/ExponentialMovingAverage', '')
    
    name_pt, tensor_pt = tf2pt(name_tf, tensor_tf)
    shape_pt = tuple(state_dict_pt[name_pt].shape)
    print(f'{str(shape_pt):18}', name_pt)
    
    if sum(shape_tf) != sum(shape_pt):
        raise ValueError
        
    if name_pt not in state_dict_pt:
        raise KeyError('Wenqi')
    
    state_dict_pt[name_pt] = tensor_pt
    print()
torch.save(state_dict_pt, state_dict_pt_path)
model.load_state_dict(state_dict_pt);
# Out:
# 100%|██████████| 168/168 [00:00<00:00, 5638.77it/s]
# State ditionary will be saved to state_dict_pt.pth
# (16,)              conv_0_bn_relu/bn_/beta
# (16,)              block.0.convolutional_block.2.bias
#
# (16,)              conv_0_bn_relu/bn_/gamma
# (16,)              block.0.convolutional_block.2.weight
#
# (16,)              conv_0_bn_relu/bn_/moving_mean
# (16,)              block.0.convolutional_block.2.running_mean
#
# (16,)              conv_0_bn_relu/bn_/moving_variance
# (16,)              block.0.convolutional_block.2.running_var
#
# (3, 3, 3, 1, 16)   conv_0_bn_relu/conv_/w
# (16, 1, 3, 3, 3)   block.0.convolutional_block.1.weight
#
# (80,)              conv_1_bn_relu/bn_/beta
# (80,)              block.4.convolutional_block.1.bias
#
# (80,)              conv_1_bn_relu/bn_/gamma
# (80,)              block.4.convolutional_block.1.weight
#
# (80,)              conv_1_bn_relu/bn_/moving_mean
# (80,)              block.4.convolutional_block.1.running_mean
#
# (80,)              conv_1_bn_relu/bn_/moving_variance
# (80,)              block.4.convolutional_block.1.running_var
#
# (1, 1, 1, 64, 80)  conv_1_bn_relu/conv_/w
# (80, 64, 1, 1, 1)  block.4.convolutional_block.0.weight
#
# (160,)             conv_2_bn/bn_/beta
# (160,)             block.6.convolutional_block.1.bias
#
# (160,)             conv_2_bn/bn_/gamma
# (160,)             block.6.convolutional_block.1.weight
#
# (160,)             conv_2_bn/bn_/moving_mean
# (160,)             block.6.convolutional_block.1.running_mean
#
# (160,)             conv_2_bn/bn_/moving_variance
# (160,)             block.6.convolutional_block.1.running_var
#
# (1, 1, 1, 80, 160) conv_2_bn/conv_/w
# (160, 80, 1, 1, 1) block.6.convolutional_block.0.weight
#
# (16,)              res_1_0/bn_0/beta
# (16,)              block.1.dilation_block.0.residual_block.0.convolutional_block.0.bias
#
# (16,)              res_1_0/bn_0/gamma
# (16,)              block.1.dilation_block.0.residual_block.0.convolutional_block.0.weight
#
# (16,)              res_1_0/bn_0/moving_mean
# (16,)              block.1.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
#
# (16,)              res_1_0/bn_0/moving_variance
# (16,)              block.1.dilation_block.0.residual_block.0.convolutional_block.0.running_var
#
# (16,)              res_1_0/bn_1/beta
# (16,)              block.1.dilation_block.0.residual_block.1.convolutional_block.0.bias
#
# (16,)              res_1_0/bn_1/gamma
# (16,)              block.1.dilation_block.0.residual_block.1.convolutional_block.0.weight
#
# (16,)              res_1_0/bn_1/moving_mean
# (16,)              block.1.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
#
# (16,)              res_1_0/bn_1/moving_variance
# (16,)              block.1.dilation_block.0.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 16, 16)  res_1_0/conv_0/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.0.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 16, 16)  res_1_0/conv_1/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.0.residual_block.1.convolutional_block.3.weight
#
# (16,)              res_1_1/bn_0/beta
# (16,)              block.1.dilation_block.1.residual_block.0.convolutional_block.0.bias
#
# (16,)              res_1_1/bn_0/gamma
# (16,)              block.1.dilation_block.1.residual_block.0.convolutional_block.0.weight
#
# (16,)              res_1_1/bn_0/moving_mean
# (16,)              block.1.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
#
# (16,)              res_1_1/bn_0/moving_variance
# (16,)              block.1.dilation_block.1.residual_block.0.convolutional_block.0.running_var
#
# (16,)              res_1_1/bn_1/beta
# (16,)              block.1.dilation_block.1.residual_block.1.convolutional_block.0.bias
#
# (16,)              res_1_1/bn_1/gamma
# (16,)              block.1.dilation_block.1.residual_block.1.convolutional_block.0.weight
#
# (16,)              res_1_1/bn_1/moving_mean
# (16,)              block.1.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
#
# (16,)              res_1_1/bn_1/moving_variance
# (16,)              block.1.dilation_block.1.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 16, 16)  res_1_1/conv_0/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.1.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 16, 16)  res_1_1/conv_1/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.1.residual_block.1.convolutional_block.3.weight
#
# (16,)              res_1_2/bn_0/beta
# (16,)              block.1.dilation_block.2.residual_block.0.convolutional_block.0.bias
#
# (16,)              res_1_2/bn_0/gamma
# (16,)              block.1.dilation_block.2.residual_block.0.convolutional_block.0.weight
#
# (16,)              res_1_2/bn_0/moving_mean
# (16,)              block.1.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
#
# (16,)              res_1_2/bn_0/moving_variance
# (16,)              block.1.dilation_block.2.residual_block.0.convolutional_block.0.running_var
#
# (16,)              res_1_2/bn_1/beta
# (16,)              block.1.dilation_block.2.residual_block.1.convolutional_block.0.bias
#
# (16,)              res_1_2/bn_1/gamma
# (16,)              block.1.dilation_block.2.residual_block.1.convolutional_block.0.weight
#
# (16,)              res_1_2/bn_1/moving_mean
# (16,)              block.1.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
#
# (16,)              res_1_2/bn_1/moving_variance
# (16,)              block.1.dilation_block.2.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 16, 16)  res_1_2/conv_0/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.2.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 16, 16)  res_1_2/conv_1/w
# (16, 16, 3, 3, 3)  block.1.dilation_block.2.residual_block.1.convolutional_block.3.weight
#
# (16,)              res_2_0/bn_0/beta
# (16,)              block.2.dilation_block.0.residual_block.0.convolutional_block.0.bias
#
# (16,)              res_2_0/bn_0/gamma
# (16,)              block.2.dilation_block.0.residual_block.0.convolutional_block.0.weight
#
# (16,)              res_2_0/bn_0/moving_mean
# (16,)              block.2.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
#
# (16,)              res_2_0/bn_0/moving_variance
# (16,)              block.2.dilation_block.0.residual_block.0.convolutional_block.0.running_var
#
# (32,)              res_2_0/bn_1/beta
# (32,)              block.2.dilation_block.0.residual_block.1.convolutional_block.0.bias
#
# (32,)              res_2_0/bn_1/gamma
# (32,)              block.2.dilation_block.0.residual_block.1.convolutional_block.0.weight
#
# (32,)              res_2_0/bn_1/moving_mean
# (32,)              block.2.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
#
# (32,)              res_2_0/bn_1/moving_variance
# (32,)              block.2.dilation_block.0.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 16, 32)  res_2_0/conv_0/w
# (32, 16, 3, 3, 3)  block.2.dilation_block.0.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 32, 32)  res_2_0/conv_1/w
# (32, 32, 3, 3, 3)  block.2.dilation_block.0.residual_block.1.convolutional_block.3.weight
#
# (32,)              res_2_1/bn_0/beta
# (32,)              block.2.dilation_block.1.residual_block.0.convolutional_block.0.bias
#
# (32,)              res_2_1/bn_0/gamma
# (32,)              block.2.dilation_block.1.residual_block.0.convolutional_block.0.weight
#
# (32,)              res_2_1/bn_0/moving_mean
# (32,)              block.2.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
#
# (32,)              res_2_1/bn_0/moving_variance
# (32,)              block.2.dilation_block.1.residual_block.0.convolutional_block.0.running_var
#
# (32,)              res_2_1/bn_1/beta
# (32,)              block.2.dilation_block.1.residual_block.1.convolutional_block.0.bias
#
# (32,)              res_2_1/bn_1/gamma
# (32,)              block.2.dilation_block.1.residual_block.1.convolutional_block.0.weight
#
# (32,)              res_2_1/bn_1/moving_mean
# (32,)              block.2.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
#
# (32,)              res_2_1/bn_1/moving_variance
# (32,)              block.2.dilation_block.1.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 32, 32)  res_2_1/conv_0/w
# (32, 32, 3, 3, 3)  block.2.dilation_block.1.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 32, 32)  res_2_1/conv_1/w
# (32, 32, 3, 3, 3)  block.2.dilation_block.1.residual_block.1.convolutional_block.3.weight
#
# (32,)              res_2_2/bn_0/beta
# (32,)              block.2.dilation_block.2.residual_block.0.convolutional_block.0.bias
#
# (32,)              res_2_2/bn_0/gamma
# (32,)              block.2.dilation_block.2.residual_block.0.convolutional_block.0.weight
#
# (32,)              res_2_2/bn_0/moving_mean
# (32,)              block.2.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
#
# (32,)              res_2_2/bn_0/moving_variance
# (32,)              block.2.dilation_block.2.residual_block.0.convolutional_block.0.running_var
#
# (32,)              res_2_2/bn_1/beta
# (32,)              block.2.dilation_block.2.residual_block.1.convolutional_block.0.bias
#
# (32,)              res_2_2/bn_1/gamma
# (32,)              block.2.dilation_block.2.residual_block.1.convolutional_block.0.weight
#
# (32,)              res_2_2/bn_1/moving_mean
# (32,)              block.2.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
#
# (32,)              res_2_2/bn_1/moving_variance
# (32,)              block.2.dilation_block.2.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 32, 32)  res_2_2/conv_0/w
# (32, 32, 3, 3, 3)  block.2.dilation_block.2.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 32, 32)  res_2_2/conv_1/w
# (32, 32, 3, 3, 3)  block.2.dilation_block.2.residual_block.1.convolutional_block.3.weight
#
# (32,)              res_3_0/bn_0/beta
# (32,)              block.3.dilation_block.0.residual_block.0.convolutional_block.0.bias
#
# (32,)              res_3_0/bn_0/gamma
# (32,)              block.3.dilation_block.0.residual_block.0.convolutional_block.0.weight
#
# (32,)              res_3_0/bn_0/moving_mean
# (32,)              block.3.dilation_block.0.residual_block.0.convolutional_block.0.running_mean
#
# (32,)              res_3_0/bn_0/moving_variance
# (32,)              block.3.dilation_block.0.residual_block.0.convolutional_block.0.running_var
#
# (64,)              res_3_0/bn_1/beta
# (64,)              block.3.dilation_block.0.residual_block.1.convolutional_block.0.bias
#
# (64,)              res_3_0/bn_1/gamma
# (64,)              block.3.dilation_block.0.residual_block.1.convolutional_block.0.weight
#
# (64,)              res_3_0/bn_1/moving_mean
# (64,)              block.3.dilation_block.0.residual_block.1.convolutional_block.0.running_mean
#
# (64,)              res_3_0/bn_1/moving_variance
# (64,)              block.3.dilation_block.0.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 32, 64)  res_3_0/conv_0/w
# (64, 32, 3, 3, 3)  block.3.dilation_block.0.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 64, 64)  res_3_0/conv_1/w
# (64, 64, 3, 3, 3)  block.3.dilation_block.0.residual_block.1.convolutional_block.3.weight
#
# (64,)              res_3_1/bn_0/beta
# (64,)              block.3.dilation_block.1.residual_block.0.convolutional_block.0.bias
#
# (64,)              res_3_1/bn_0/gamma
# (64,)              block.3.dilation_block.1.residual_block.0.convolutional_block.0.weight
#
# (64,)              res_3_1/bn_0/moving_mean
# (64,)              block.3.dilation_block.1.residual_block.0.convolutional_block.0.running_mean
#
# (64,)              res_3_1/bn_0/moving_variance
# (64,)              block.3.dilation_block.1.residual_block.0.convolutional_block.0.running_var
#
# (64,)              res_3_1/bn_1/beta
# (64,)              block.3.dilation_block.1.residual_block.1.convolutional_block.0.bias
#
# (64,)              res_3_1/bn_1/gamma
# (64,)              block.3.dilation_block.1.residual_block.1.convolutional_block.0.weight
#
# (64,)              res_3_1/bn_1/moving_mean
# (64,)              block.3.dilation_block.1.residual_block.1.convolutional_block.0.running_mean
#
# (64,)              res_3_1/bn_1/moving_variance
# (64,)              block.3.dilation_block.1.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 64, 64)  res_3_1/conv_0/w
# (64, 64, 3, 3, 3)  block.3.dilation_block.1.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 64, 64)  res_3_1/conv_1/w
# (64, 64, 3, 3, 3)  block.3.dilation_block.1.residual_block.1.convolutional_block.3.weight
#
# (64,)              res_3_2/bn_0/beta
# (64,)              block.3.dilation_block.2.residual_block.0.convolutional_block.0.bias
#
# (64,)              res_3_2/bn_0/gamma
# (64,)              block.3.dilation_block.2.residual_block.0.convolutional_block.0.weight
#
# (64,)              res_3_2/bn_0/moving_mean
# (64,)              block.3.dilation_block.2.residual_block.0.convolutional_block.0.running_mean
#
# (64,)              res_3_2/bn_0/moving_variance
# (64,)              block.3.dilation_block.2.residual_block.0.convolutional_block.0.running_var
#
# (64,)              res_3_2/bn_1/beta
# (64,)              block.3.dilation_block.2.residual_block.1.convolutional_block.0.bias
#
# (64,)              res_3_2/bn_1/gamma
# (64,)              block.3.dilation_block.2.residual_block.1.convolutional_block.0.weight
#
# (64,)              res_3_2/bn_1/moving_mean
# (64,)              block.3.dilation_block.2.residual_block.1.convolutional_block.0.running_mean
#
# (64,)              res_3_2/bn_1/moving_variance
# (64,)              block.3.dilation_block.2.residual_block.1.convolutional_block.0.running_var
#
# (3, 3, 3, 64, 64)  res_3_2/conv_0/w
# (64, 64, 3, 3, 3)  block.3.dilation_block.2.residual_block.0.convolutional_block.3.weight
#
# (3, 3, 3, 64, 64)  res_3_2/conv_1/w
# (64, 64, 3, 3, 3)  block.3.dilation_block.2.residual_block.1.convolutional_block.3.weight
